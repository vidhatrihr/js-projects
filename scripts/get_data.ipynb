# %%
import os
import json
from datetime import datetime

# %%
f = open('../assets/projects_data.json')
data = json.load(f)
data[0]
# Out:
# {'title': 'Basic Calculator',
#  'description': 'A simple calculator app with standard arithmetic operations and a clean interface',
#  'date': '2025-08-16',
#  'tags': ['Logic', 'UI'],
#  'slug': 'basic-calculator'}

# %%
for project in data:
  index_path = f'../{project['slug']}/index.html'
  ctime = os.path.getctime(index_path)
  project['date'] = datetime.fromtimestamp(ctime).strftime('20%y-%m-%d')
  # print(project['date'])

# %%
data.sort(key=lambda project: project['date'])

# %%
f = open('../assets/projects_data.json', 'w')
json.dump(data, f, indent=2)
f.close()
